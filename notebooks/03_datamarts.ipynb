# %% [markdown]
# # 🧱 03 — Construction des datamarts
#
# 6 tables agrégées, une par cas d'usage analytique.

# %%
import sys
sys.path.append('..')

from src.data_loader import load_processed, save_datamart, save_export
from src.datamarts import build_all

df = load_processed()
dms = build_all(df)
print('Datamarts construits :', list(dms.keys()))

# %% [markdown]
# ## 1. KPIs globaux

# %%
dms['global_kpis']

# %% [markdown]
# ## 2. Impact par industrie

# %%
dms['industry_impact'].sort_values('pct_replaced', ascending=False)

# %% [markdown]
# ## 3. Impact par métier (top 10)

# %%
dms['role_impact'].head(10)

# %% [markdown]
# ## 4. Démographie

# %%
dms['demographics'].head(10)

# %% [markdown]
# ## 5. Matrice adoption × risque

# %%
dms['adoption_risk_matrix']

# %% [markdown]
# ## 6. Upskilling outcomes

# %%
dms['upskilling_outcomes']

# %% [markdown]
# ## Sauvegarde des datamarts + exports Looker

# %%
for name, dm in dms.items():
    path = save_datamart(dm, name)
    print(f'✓ {path.name}')

# Export du dataset complet pour Looker
save_export(df, 'main_dataset.csv')
print('\n✓ main_dataset.csv exporté pour Looker Studio')
