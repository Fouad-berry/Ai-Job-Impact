# %% [markdown]
# # 🎨 04 — Visualisations
#
# Les 10 figures finales sont pré-générées dans `images/figures/` par `build_project.py`.
# Ce notebook montre comment les reproduire et les personnaliser.

# %%
import sys
sys.path.append('..')

import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_processed, load_datamart
from src.visualizations import (
    set_style, plot_job_status, plot_replacement_by_industry,
    plot_productivity_heatmap, plot_salary_distribution
)

set_style()
df = load_processed()
dm_industry = load_datamart('industry_impact')

# %% [markdown]
# ## Répartition Job Status

# %%
plot_job_status(df); plt.show()

# %% [markdown]
# ## Remplacement par industrie

# %%
plot_replacement_by_industry(dm_industry); plt.show()

# %% [markdown]
# ## Heatmap productivité

# %%
plot_productivity_heatmap(df); plt.show()

# %% [markdown]
# ## Distribution du changement salarial

# %%
plot_salary_distribution(df); plt.show()

# %% [markdown]
# ## Bonus : satisfaction par industrie × statut

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Industry', y='Job_Satisfaction', hue='Job_Status',
            palette={'Unchanged': '#2ecc71', 'Modified': '#f39c12', 'Replaced': '#e74c3c'})
plt.xticks(rotation=30, ha='right')
plt.title('Satisfaction par industrie selon le statut de l\'emploi')
plt.show()
